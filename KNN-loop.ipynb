# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
path = "./iris.data"
headernames = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'Class']
dataset = pd.read_csv(path, names = headernames)
dataset.head()
# Out:
#    sepal-length  sepal-width  petal-length  petal-width        Class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 4].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.40)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
#train the model with the help of KNeighborsClassifier class of sklearn 
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
for i in range(1,20):
    classifier = KNeighborsClassifier(n_neighbors = i)
    classifier.fit(X_train, y_train)
    y_pred = classifier.predict(X_test)
    result = confusion_matrix(y_test, y_pred)
    print("Confusion Matrix:")
    print(result)
    result1 = classification_report(y_test, y_pred)
    print("Classification Report:",result1)
    result2 = accuracy_score(y_test,y_pred)
    print("i", i,"Accuracy:",result2)
# Out:
# Confusion Matrix:
# [[21  1  0]
#  [ 0 19  3]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      0.95      0.98        22
# Iris-versicolor       0.86      0.86      0.86        22
#  Iris-virginica       0.82      0.88      0.85        16
#
#       micro avg       0.90      0.90      0.90        60
#       macro avg       0.90      0.90      0.90        60
#    weighted avg       0.90      0.90      0.90        60
#
# i 1 Accuracy: 0.9
# Confusion Matrix:
# [[22  0  0]
#  [ 0 19  3]
#  [ 0  4 12]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.83      0.86      0.84        22
#  Iris-virginica       0.80      0.75      0.77        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.88      0.87      0.87        60
#    weighted avg       0.88      0.88      0.88        60
#
# i 2 Accuracy: 0.8833333333333333
# Confusion Matrix:
# [[22  0  0]
#  [ 0 19  3]
#  [ 0  3 13]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.86      0.86      0.86        22
#  Iris-virginica       0.81      0.81      0.81        16
#
#       micro avg       0.90      0.90      0.90        60
#       macro avg       0.89      0.89      0.89        60
#    weighted avg       0.90      0.90      0.90        60
#
# i 3 Accuracy: 0.9
# Confusion Matrix:
# [[22  0  0]
#  [ 0 19  3]
#  [ 0  4 12]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.83      0.86      0.84        22
#  Iris-virginica       0.80      0.75      0.77        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.88      0.87      0.87        60
#    weighted avg       0.88      0.88      0.88        60
#
# i 4 Accuracy: 0.8833333333333333
# Confusion Matrix:
# [[22  0  0]
#  [ 0 17  5]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.89      0.77      0.83        22
#  Iris-virginica       0.74      0.88      0.80        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.88      0.88      0.88        60
#    weighted avg       0.89      0.88      0.88        60
#
# i 5 Accuracy: 0.8833333333333333
# Confusion Matrix:
# [[22  0  0]
#  [ 0 18  4]
#  [ 0  4 12]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.82      0.82      0.82        22
#  Iris-virginica       0.75      0.75      0.75        16
#
#       micro avg       0.87      0.87      0.87        60
#       macro avg       0.86      0.86      0.86        60
#    weighted avg       0.87      0.87      0.87        60
#
# i 6 Accuracy: 0.8666666666666667
# Confusion Matrix:
# [[22  0  0]
#  [ 0 17  5]
#  [ 0  3 13]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.85      0.77      0.81        22
#  Iris-virginica       0.72      0.81      0.76        16
#
#       micro avg       0.87      0.87      0.87        60
#       macro avg       0.86      0.86      0.86        60
#    weighted avg       0.87      0.87      0.87        60
#
# i 7 Accuracy: 0.8666666666666667
# Confusion Matrix:
# [[22  0  0]
#  [ 0 18  4]
#  [ 0  3 13]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.86      0.82      0.84        22
#  Iris-virginica       0.76      0.81      0.79        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.87      0.88      0.88        60
#    weighted avg       0.88      0.88      0.88        60
#
# i 8 Accuracy: 0.8833333333333333
# Confusion Matrix:
# [[22  0  0]
#  [ 0 17  5]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.89      0.77      0.83        22
#  Iris-virginica       0.74      0.88      0.80        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.88      0.88      0.88        60
#    weighted avg       0.89      0.88      0.88        60
#
# i 9 Accuracy: 0.8833333333333333
# Confusion Matrix:
# [[22  0  0]
#  [ 0 18  4]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.90      0.82      0.86        22
#  Iris-virginica       0.78      0.88      0.82        16
#
#       micro avg       0.90      0.90      0.90        60
#       macro avg       0.89      0.90      0.89        60
#    weighted avg       0.90      0.90      0.90        60
#
# i 10 Accuracy: 0.9
# Confusion Matrix:
# [[22  0  0]
#  [ 0 17  5]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.89      0.77      0.83        22
#  Iris-virginica       0.74      0.88      0.80        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.88      0.88      0.88        60
#    weighted avg       0.89      0.88      0.88        60
#
# i 11 Accuracy: 0.8833333333333333
# Confusion Matrix:
# [[22  0  0]
#  [ 0 18  4]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.90      0.82      0.86        22
#  Iris-virginica       0.78      0.88      0.82        16
#
#       micro avg       0.90      0.90      0.90        60
#       macro avg       0.89      0.90      0.89        60
#    weighted avg       0.90      0.90      0.90        60
#
# i 12 Accuracy: 0.9
# Confusion Matrix:
# [[22  0  0]
#  [ 0 18  4]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.90      0.82      0.86        22
#  Iris-virginica       0.78      0.88      0.82        16
#
#       micro avg       0.90      0.90      0.90        60
#       macro avg       0.89      0.90      0.89        60
#    weighted avg       0.90      0.90      0.90        60
#
# i 13 Accuracy: 0.9
# Confusion Matrix:
# [[22  0  0]
#  [ 0 18  4]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.90      0.82      0.86        22
#  Iris-virginica       0.78      0.88      0.82        16
#
#       micro avg       0.90      0.90      0.90        60
#       macro avg       0.89      0.90      0.89        60
#    weighted avg       0.90      0.90      0.90        60
#
# i 14 Accuracy: 0.9
# Confusion Matrix:
# [[22  0  0]
#  [ 0 16  6]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.89      0.73      0.80        22
#  Iris-virginica       0.70      0.88      0.78        16
#
#       micro avg       0.87      0.87      0.87        60
#       macro avg       0.86      0.87      0.86        60
#    weighted avg       0.88      0.87      0.87        60
#
# i 15 Accuracy: 0.8666666666666667
# Confusion Matrix:
# [[22  0  0]
#  [ 0 16  6]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.89      0.73      0.80        22
#  Iris-virginica       0.70      0.88      0.78        16
#
#       micro avg       0.87      0.87      0.87        60
#       macro avg       0.86      0.87      0.86        60
#    weighted avg       0.88      0.87      0.87        60
#
# i 16 Accuracy: 0.8666666666666667
# Confusion Matrix:
# [[22  0  0]
#  [ 0 15  7]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.88      0.68      0.77        22
#  Iris-virginica       0.67      0.88      0.76        16
#
#       micro avg       0.85      0.85      0.85        60
#       macro avg       0.85      0.85      0.84        60
#    weighted avg       0.87      0.85      0.85        60
#
# i 17 Accuracy: 0.85
# Confusion Matrix:
# [[22  0  0]
#  [ 0 15  7]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.88      0.68      0.77        22
#  Iris-virginica       0.67      0.88      0.76        16
#
#       micro avg       0.85      0.85      0.85        60
#       macro avg       0.85      0.85      0.84        60
#    weighted avg       0.87      0.85      0.85        60
#
# i 18 Accuracy: 0.85
# Confusion Matrix:
# [[22  0  0]
#  [ 0 14  8]
#  [ 0  2 14]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.88      0.64      0.74        22
#  Iris-virginica       0.64      0.88      0.74        16
#
#       micro avg       0.83      0.83      0.83        60
#       macro avg       0.84      0.84      0.82        60
#    weighted avg       0.86      0.83      0.83        60
#
# i 19 Accuracy: 0.8333333333333334

# %%
# Out:
# Confusion Matrix: [[22  0  0]
#  [ 0 19  3]
#  [ 0  4 12]]
# Classification Report:                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        22
# Iris-versicolor       0.83      0.86      0.84        22
#  Iris-virginica       0.80      0.75      0.77        16
#
#       micro avg       0.88      0.88      0.88        60
#       macro avg       0.88      0.87      0.87        60
#    weighted avg       0.88      0.88      0.88        60
#
# Accuracy: 0.8833333333333333
