# %%
import pdfplumber

# %%
file_path = "/Users/dengwei/projects/work/cash/klgocr/pytest/bankstatement/StateBankofIndia.pdf"
pdf= pdfplumber.open(file_path)
p = pdf.pages[0]

# %%
p.extract_words()
# Out:
# [{'x0': Decimal('36.000'),
#   'x1': Decimal('68.517'),
#   'top': Decimal('94.959'),
#   'bottom': Decimal('105.363'),
#   'text': 'Account'},
#  {'x0': Decimal('71.019'),
#   'x1': Decimal('95.022'),
#   'top': Decimal('94.959'),
#   'bottom': Decimal('105.363'),
#   'text': 'Name'},
#  {'x0': Decimal('142.560'),
#   'x1': Decimal('158.058'),
#   'top': Decimal('94.959'),
#   'bottom': Decimal('105.363'),
#   'text': ':(cid:9)Mr.'},
#  {'x0': Decimal('160.560'),
#   'x1': Decimal('193.563'),
#   'top': Decimal('94.959'),
#   'bottom': Decimal('105.363'),
#   'text': 'SHANTI'},
#  {'x0': Decimal('196.065'),
#   'x1': Decimal('240.066'),
#   'top': Decimal('94.959'),
#   'bottom': Decimal('105.363'),
#   'text': 'BHUSHAN'},
#  {'x0': Decimal('245.070'),
#   'x1': Decimal('286.074'),
#   'top': Decimal('94.959'),
#   'bottom': Decimal('105.363'),
#   'text': 'TRIPATHI'},
#  {'x0': Decimal('36.000'),
#   'x1': Decimal('69.012'),
#   'top': Decimal('108.459'),
# ...

# %%
im = p.to_image()
im.draw_rects(p.extract_words())

# %%
im.save("./sbi.png" , format="PNG")

# %%
p = pdf.pages[0]
im = p.to_image()
im.save("./sbi2.png" , format="PNG")

# %%
import cv2
# Out:
# --------------------------------------------------------------
# ModuleNotFoundError          Traceback (most recent call last)
# <ipython-input-8-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'
